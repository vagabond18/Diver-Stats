# %%
# Import functions from analyze_stats.py
import importlib
import sys

# Remove cached module if it exists
if 'analyze_stats' in sys.modules:
    importlib.reload(sys.modules['analyze_stats'])

from analyze_stats import (
    load_data, 
    calculate_basic_stats,
    print_summary,
    create_kill_breakdown_chart,
    create_combat_style_chart,
    create_mission_stats_chart,
    create_stratagem_usage_chart
)
from pathlib import Path
import matplotlib.pyplot as plt

# Configure matplotlib for inline display
# %matplotlib inline

print("[PASSED] Functions imported successfully")
# Out:
# [PASSED] Functions imported successfully

# %% [markdown]
# ## Load Data

# %%
# Load data from CSV
csv_file = Path('assets/26Feb2025.csv')
stats = load_data(csv_file)
print(f"[PASSED] Data loaded from {csv_file}")
print(f"Total missions: {stats['Missions Played']:,}")
# Out:
# [PASSED] Data loaded from assets/26Feb2025.csv
# Total missions: 2,723

# %% [markdown]
# ## Calculate and Display Statistics

# %%
# Calculate statistics
calculated_stats = calculate_basic_stats(stats)

# Print summary
print_summary(stats, calculated_stats)
# Out:
# ...
# HELLDIVERS 2 STATISTICS SUMMARY
# ...
#
# MISSION STATISTICS
#   • Total Missions: 2,723
#   • Missions Won: 2,614
#   • Success Rate: 96.0%
#   • Extraction Rate: 84.1%
#
# COMBAT STATISTICS
#   • Total Kills: 307,326
#   • Terminid: 78,632
#   • Automaton: 200,079
#   • Illuminate: 28,615
#   • K/D Ratio: 278714.75
#   • Accuracy: 51.8%
#
# AVERAGES PER MISSION
#   • XP Earned: 1,153
#   • Samples: 17.4
#   • Objectives: 5.0
#
# ...

# %% [markdown]
# ## Visualization 1: Kill Breakdown

# %%
# Display kill breakdown chart inline
create_kill_breakdown_chart(stats)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Display kill breakdown chart inline
# ----> 2 create_kill_breakdown_chart(stats, None)
#       3 plt.show()
#
# File ~/Diver-Stats/analyze_stats.py:67, in create_kill_breakdown_chart(stats, output_dir)
#      64 plt.xticks(rotation=15, ha='right')
#      65 plt.tight_layout()
# ---> 67 if output_dir:
#      68     plt.savefig(output_dir / 'kill_breakdown.png', dpi=150, bbox_inches='tight')
#      69     plt.close()
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'str'

# %% [markdown]
# ## Visualization 2: Combat Style

# %%
# Display combat style chart inline
create_combat_style_chart(stats)
plt.show()

# %% [markdown]
# ## Visualization 3: Mission Statistics

# %%
# Display mission statistics chart inline
create_mission_stats_chart(stats)
plt.show()

# %% [markdown]
# ## Visualization 4: Stratagem Usage

# %%
# Display stratagem usage chart inline
create_stratagem_usage_chart(stats)
plt.show()

# %% [markdown]
# ## Summary
#
# All visualizations are displayed inline above. The functions are imported from `analyze_stats.py`, making the code reusable and maintainable.
#
# You can:
# - Modify the visualization functions in `analyze_stats.py`
# - Change the CSV file path in the Load Data section
# - Re-run any cell to update the analysis
